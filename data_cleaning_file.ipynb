# %%
import pandas as pd
import numpy as np
import re
from re import sub
import multiprocessing
import unidecode

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec
from gensim.test.utils import get_tmpfile
from gensim.models import KeyedVectors


from time import time 
from collections import defaultdict

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
file = pd.read_csv(r"C:\Users\15145\Documents\text analytics\Analysis_Final.csv")

# %%
file
# Out:
#               userid    date  \
# 0         libertycat  Mar-03
# 1           tidester  Mar-03
# 2            jlp8885  Mar-03
# 3       dieselbreath  Mar-03
# 4            gagrice  Mar-03
# ...              ...     ...
# 4996  tired_old_dave  Apr-06
# 4997         jimhemi  Apr-06
# 4998         jimhemi  Apr-06
# 4999        caribou1  Apr-06
# 5000         winter2  Apr-06
#
#                                                 comment
# 0         I'm not due to the smell and noise of diesel.
# 1     I really think you should take this over to th...
# 2     today's diesels- common rail or even the old v...
# 3     I suspect it may get the Benz E300D power-plan...
# 4     It may be the co-op in Volga. That is where he...
# ...                                                 ...
# 4996  atf+4 is dc tranny fluid. What are they using ...
# 4997  Maybe you're onto something. Crack the egg, ma...
# 4998  Take it it a Detroit Diesel Repair shop. DC ow...
# 4999  How would you react if a (really good and seri...
# 5000  Dave,The level of the fluid in the reservoir w...
#
# [5001 rows x 3 columns]

# %%
file_cleaned = file.dropna().drop_duplicates().reset_index(drop=True).rename(columns={'comment':'title'})

# %%
file_cleaned
# Out:
#               userid    date  \
# 0         libertycat  Mar-03
# 1           tidester  Mar-03
# 2            jlp8885  Mar-03
# 3       dieselbreath  Mar-03
# 4            gagrice  Mar-03
# ...              ...     ...
# 4991  tired_old_dave  Apr-06
# 4992         jimhemi  Apr-06
# 4993         jimhemi  Apr-06
# 4994        caribou1  Apr-06
# 4995         winter2  Apr-06
#
#                                                   title
# 0         I'm not due to the smell and noise of diesel.
# 1     I really think you should take this over to th...
# 2     today's diesels- common rail or even the old v...
# 3     I suspect it may get the Benz E300D power-plan...
# 4     It may be the co-op in Volga. That is where he...
# ...                                                 ...
# 4991  atf+4 is dc tranny fluid. What are they using ...
# 4992  Maybe you're onto something. Crack the egg, ma...
# 4993  Take it it a Detroit Diesel Repair shop. DC ow...
# 4994  How would you react if a (really good and seri...
# 4995  Dave,The level of the fluid in the reservoir w...
#
# [4996 rows x 3 columns]

# %%
file_cleaned.userid.value_counts()/len(file_cleaned)
# Out:
# caribou1          0.085068
# winter2           0.076861
# farout            0.055044
# tired_old_dave    0.036829
# moparbad          0.036229
#                     ...
# drobinson         0.000200
# rs_petty          0.000200
# crdlibertyownr    0.000200
# isis2             0.000200
# farm101           0.000200
# Name: userid, Length: 459, dtype: float64

# %%
file_cleaned[file_cleaned.userid==0]
# Out:
# Empty DataFrame
# Columns: [userid, date, title]
# Index: []

# %%
file_cleaned = file_cleaned[file_cleaned.userid!=0]

# %%
file_cleaned.userid.value_counts()/len(file_cleaned)
# Out:
# caribou1          0.085068
# winter2           0.076861
# farout            0.055044
# tired_old_dave    0.036829
# moparbad          0.036229
#                     ...
# drobinson         0.000200
# rs_petty          0.000200
# crdlibertyownr    0.000200
# isis2             0.000200
# farm101           0.000200
# Name: userid, Length: 459, dtype: float64

# %%
def text_to_word_list(text, remove_polish_letters):
    ''' Pre process and convert texts to a list of words 
    method inspired by method from eliorc github repo: https://github.com/eliorc/Medium/blob/master/MaLSTM.ipynb'''
    #text = remove_polish_letters(text)
    text = str(text)
    text = text.lower()

    # Clean the text
    text = sub(r"[^A-Za-z0-9^,!?.\/'+]", " ", text)
    text = sub(r"\+", " plus ", text)
    text = sub(r",", " ", text)
    text = sub(r"\.", " ", text)
    text = sub(r"!", " ! ", text)
    text = sub(r"\?", " ? ", text)
    text = sub(r"'", " ", text)
    text = sub(r":", " : ", text)
    text = sub(r"\s{2,}", " ", text)

    text = text.split()

    return text

# %%
file_cleaned.title = file_cleaned.title.apply(lambda x: text_to_word_list(x, unidecode))

# %%
file_cleaned.title
# Out:
# 0       [i, m, not, due, to, the, smell, and, noise, o...
# 1       [i, really, think, you, should, take, this, ov...
# 2       [today, s, diesels, common, rail, or, even, th...
# 3       [i, suspect, it, may, get, the, benz, e300d, p...
# 4       [it, may, be, the, co, op, in, volga, that, is...
#                               ...
# 4991    [atf, plus, 4, is, dc, tranny, fluid, what, ar...
# 4992    [maybe, you, re, onto, something, crack, the, ...
# 4993    [take, it, it, a, detroit, diesel, repair, sho...
# 4994    [how, would, you, react, if, a, really, good, ...
# 4995    [dave, the, level, of, the, fluid, in, the, re...
# Name: title, Length: 4996, dtype: object

# %%
file_model = file_cleaned.copy()
file_model = file_model[file_model.title.str.len()>1]

# %%
file_model
# Out:
#               userid    date  \
# 0         libertycat  Mar-03
# 1           tidester  Mar-03
# 2            jlp8885  Mar-03
# 3       dieselbreath  Mar-03
# 4            gagrice  Mar-03
# ...              ...     ...
# 4991  tired_old_dave  Apr-06
# 4992         jimhemi  Apr-06
# 4993         jimhemi  Apr-06
# 4994        caribou1  Apr-06
# 4995         winter2  Apr-06
#
#                                                   title
# 0     [i, m, not, due, to, the, smell, and, noise, o...
# 1     [i, really, think, you, should, take, this, ov...
# 2     [today, s, diesels, common, rail, or, even, th...
# 3     [i, suspect, it, may, get, the, benz, e300d, p...
# 4     [it, may, be, the, co, op, in, volga, that, is...
# ...                                                 ...
# 4991  [atf, plus, 4, is, dc, tranny, fluid, what, ar...
# 4992  [maybe, you, re, onto, something, crack, the, ...
# 4993  [take, it, it, a, detroit, diesel, repair, sho...
# 4994  [how, would, you, react, if, a, really, good, ...
# 4995  [dave, the, level, of, the, fluid, in, the, re...
#
# [4992 rows x 3 columns]

# %%
sent = [row for row in file_model.title]
phrases = Phrases(sent, min_count=1, progress_per=50000)
bigram = Phraser(phrases)
sentences = bigram[sent]
sentences[1]
# Out:
# INFO - 13:51:48: collecting all words and their counts
# INFO - 13:51:48: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 13:51:51: collected 196766 word types from a corpus of 491436 words (unigram + bigrams) and 4992 sentences
# INFO - 13:51:51: using 196766 counts as vocab in Phrases<0 vocab, min_count=1, threshold=10.0, max_vocab_size=40000000>
# INFO - 13:51:51: source_vocab length 196766
# INFO - 13:51:57: Phraser built with 11286 phrasegrams
# ['i',
#  'really',
#  'think',
#  'you',
#  'should',
#  'take',
#  'this',
#  'over',
#  'to',
#  'the',
#  'jeep_liberty',
#  'forum',
#  'thanks',
#  '!_tidester',
#  'host']

# %%
w2v_model = Word2Vec(min_count=3,
                     window=4,
                     size=300,
                     sample=1e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=multiprocessing.cpu_count()-1)

start = time()

w2v_model.build_vocab(sentences, progress_per=50000)

print('Time to build vocab: {} mins'.format(round((time() - start) / 60, 2)))
# Out:
# INFO - 13:52:08: collecting all words and their counts
# INFO - 13:52:08: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 13:52:10: collected 27949 word types from a corpus of 430486 raw words and 4992 sentences
# INFO - 13:52:10: Loading a fresh vocabulary
# INFO - 13:52:10: effective_min_count=3 retains 11053 unique words (39% of original 27949, drops 16896)
# INFO - 13:52:10: effective_min_count=3 leaves 406733 word corpus (94% of original 430486, drops 23753)
# INFO - 13:52:10: deleting the raw counts dictionary of 27949 items
# INFO - 13:52:10: sample=1e-05 downsamples 3290 most-common words
# INFO - 13:52:10: downsampling leaves estimated 97903 word corpus (24.1% of prior 406733)
# INFO - 13:52:10: estimated required memory for 11053 words and 300 dimensions: 32053700 bytes
# INFO - 13:52:10: resetting layer weights
# Time to build vocab: 0.14 mins

# %%
start = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=15, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - start) / 60, 2)))

w2v_model.init_sims(replace=True)
# Out:
# INFO - 13:52:16: training model with 7 workers on 11053 vocabulary and 300 features, using sg=0 hs=0 sample=1e-05 negative=20 window=4
# INFO - 13:52:17: EPOCH 1 - PROGRESS: at 27.10% examples, 26251 words/s, in_qsize 1, out_qsize 0
# INFO - 13:52:18: EPOCH 1 - PROGRESS: at 56.25% examples, 26427 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:19: EPOCH 1 - PROGRESS: at 88.76% examples, 27850 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:19: worker thread finished; awaiting finish of 6 more threads
# INFO - 13:52:19: worker thread finished; awaiting finish of 5 more threads
# INFO - 13:52:19: worker thread finished; awaiting finish of 4 more threads
# INFO - 13:52:19: worker thread finished; awaiting finish of 3 more threads
# INFO - 13:52:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 13:52:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 13:52:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 13:52:19: EPOCH - 1 : training on 430486 raw words (97599 effective words) took 3.4s, 28580 effective words/s
# INFO - 13:52:21: EPOCH 2 - PROGRESS: at 27.10% examples, 26076 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:22: EPOCH 2 - PROGRESS: at 58.21% examples, 26353 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52
words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:49: EPOCH 10 - PROGRESS: at 60.22% examples, 27729 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:50: EPOCH 10 - PROGRESS: at 93.13% examples, 28622 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:50: worker thread finished; awaiting finish of 6 more threads
# INFO - 13:52:50: worker thread finished; awaiting finish of 5 more threads
# INFO - 13:52:50: worker thread finished; awaiting finish of 4 more threads
# INFO - 13:52:50: worker thread finished; awaiting finish of 3 more threads
# INFO - 13:52:50: worker thread finished; awaiting finish of 2 more threads
# INFO - 13:52:50: worker thread finished; awaiting finish of 1 more threads
# INFO - 13:52:50: worker thread finished; awaiting finish of 0 more threads
# INFO - 13:52:50: EPOCH - 10 : training on 430486 raw words (97880 effective words) took 3.4s, 29016 effective words/s
# INFO - 13:52:51: EPOCH 11 - PROGRESS: at 28.95% examples, 27054 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:52: EPOCH 11 - PROGRESS: at 62.00% examples, 28235 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:53: EPOCH 11 - PROGRESS: at 90.99% examples, 27665 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:54: worker thread finished; awaiting finish of 6 more threads
# INFO - 13:52:54: worker thread finished; awaiting finish of 5 more threads
# INFO - 13:52:54: worker thread finished; awaiting finish of 4 more threads
# INFO - 13:52:54: worker thread finished; awaiting finish of 3 more threads
# INFO - 13:52:54: worker thread finished; awaiting finish of 2 more threads
# INFO - 13:52:54: worker thread finished; awaiting finish of 1 more threads
# INFO - 13:52:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 13:52:54: EPOCH - 11 : training on 430486 raw words (97716 effective words) took 3.5s, 27973 effective words/s
# INFO - 13:52:55: EPOCH 12 - PROGRESS: at 27.10% examples, 25212 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:56: EPOCH 12 - PROGRESS: at 58.21% examples, 26529 words/s, in_qsize 1, out_qsize 0
# INFO - 13:52:57: EPOCH 12 - PROGRESS: at 88.76% examples, 27295 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:57: worker thread finished; awaiting finish of 6 more threads
# INFO - 13:52:57: worker thread finished; awaiting finish of 5 more threads
# INFO - 13:52:57: worker thread finished; awaiting finish of 4 more threads
# INFO - 13:52:57: worker thread finished; awaiting finish of 3 more threads
# INFO - 13:52:57: worker thread finished; awaiting finish of 2 more threads
# INFO - 13:52:57: worker thread finished; awaiting finish of 1 more threads
# INFO - 13:52:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 13:52:57: EPOCH - 12 : training on 430486 raw words (97889 effective words) took 3.5s, 28086 effective words/s
# INFO - 13:52:58: EPOCH 13 - PROGRESS: at 28.95% examples, 27771 words/s, in_qsize 0, out_qsize 0
# INFO - 13:52:59: EPOCH 13 - PROGRESS: at 62.00% examples, 29053 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:00: EPOCH 13 - PROGRESS: at 95.19% examples, 29617 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:01: worker thread finished; awaiting finish of 6 more threads
# INFO - 13:53:01: worker thread finished; awaiting finish of 5 more threads
# INFO - 13:53:01: worker thread finished; awaiting finish of 4 more threads
# INFO - 13:53:01: worker thread finished; awaiting finish of 3 more threads
# INFO - 13:53:01: worker thread finished; awaiting finish of 2 more threads
# INFO - 13:53:01: worker thread finished; awaiting finish of 1 more threads
# INFO - 13:53:01: worker thread finished; awaiting finish of 0 more threads
# INFO - 13:53:01: EPOCH - 13 : training on 430486 raw words (97982 effective words) took 3.3s, 30051 effective words/s
# INFO - 13:53:02: EPOCH 14 - PROGRESS: at 27.10% examples, 26706 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:03: EPOCH 14 - PROGRESS: at 62.00% examples, 29269 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:04: EPOCH 14 - PROGRESS: at 95.19% examples, 29542 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:04: worker thread finished; awaiting finish of 6 more threads
# INFO - 13:53:04: worker thread finished; awaiting finish of 5 more threads
# INFO - 13:53:04: worker thread finished; awaiting finish of 4 more threads
# INFO - 13:53:04: worker thread finished; awaiting finish of 3 more threads
# INFO - 13:53:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 13:53:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 13:53:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 13:53:04: EPOCH - 14 : training on 430486 raw words (97818 effective words) took 3.3s, 30009 effective words/s
# INFO - 13:53:05: EPOCH 15 - PROGRESS: at 28.95% examples, 28954 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:06: EPOCH 15 - PROGRESS: at 60.22% examples, 28872 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:07: EPOCH 15 - PROGRESS: at 93.13% examples, 28945 words/s, in_qsize 0, out_qsize 0
# INFO - 13:53:07: worker thread finished; awaiting finish of 6 more threads
# INFO - 13:53:07: worker thread finished; awaiting finish of 5 more threads
# INFO - 13:53:07: worker thread finished; awaiting finish of 4 more threads
# INFO - 13:53:07: worker thread finished; awaiting finish of 3 more threads
# INFO - 13:53:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 13:53:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 13:53:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 13:53:07: EPOCH - 15 : training on 430486 raw words (97716 effective words) took 3.3s, 29456 effective words/s
# INFO - 13:53:07: training on a 6457290 raw words (1467863 effective words) took 51.1s, 28715 effective words/s
# INFO - 13:53:07: precomputing L2-norms of word weight vectors
# Time to train the model: 0.85 mins

# %%
w2v_model.save("word2vec.model")
# Out:
# INFO - 13:53:07: saving Word2Vec object under word2vec.model, separately None
# INFO - 13:53:07: not storing attribute vectors_norm
# INFO - 13:53:07: not storing attribute cum_table
# INFO - 13:53:08: saved word2vec.model

# %%
file_export = file_model.copy()
file_export['old_title'] = file_export.title
file_export.old_title = file_export.old_title.str.join(' ')
file_export.title = file_export.title.apply(lambda x: ' '.join(bigram[x]))
#file_export.userid = file_export.userid.astype('int8')

# %%
file_export[['title', 'userid']].to_csv(r"C:\Users\15145\Documents\text analytics\cleaned_dataset.csv", index=False)
